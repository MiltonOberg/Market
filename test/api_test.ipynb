# %%
from backend.features.connect_api import Market

# %%
data = Market().data

# %%
data
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'IBM',
#   '3. Last Refreshed': '2025-02-12',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2025-02-12': {'1. open': '252.7200',
#    '2. high': '256.4000',
#    '3. low': '252.0200',
#    '4. close': '255.8100',
#    '5. volume': '3075308'},
#   '2025-02-11': {'1. open': '251.1000',
#    '2. high': '256.7500',
#    '3. low': '250.5800',
#    '4. close': '254.7000',
#    '5. volume': '4801550'},
#   '2025-02-10': {'1. open': '250.8600',
#    '2. high': '251.9500',
#    '3. low': '246.8700',
#    '4. close': '249.2700',
#    '5. volume': '3564400'},
#   '2025-02-07': {'1. open': '255.2800',
#    '2. high': '256.9300',
#    '3. low': '252.0200',
#    '4. close': '252.3400',
#    '5. volume': '3370284'},
#   '2025-02-06': {'1. open': '262.9800',
#    '2. high': '263.3800',
#    '3. low': '252.7300',
#    '4. close': '253.4400',
# ...
