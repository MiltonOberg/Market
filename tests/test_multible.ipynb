# %%
from backend.components.stock import Stock
from backend.features.models.multi_agent import MultiAgent
from utils.stock_list import SWEDISH_STOCKS

# %%
stock = Stock("saab")
agent = MultiAgent(stock)

history = agent.train_on_multiple(SWEDISH_STOCKS, epochs=100)
# Out:
# Skipping TELE2-B.ST, not found: Error fetching data for TELE2-B.ST: list index out of range
# Exception ignored from cffi callback <function buffer_callback at 0x00000264BBBE63E0>:
# Traceback (most recent call last):
#   File "c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\curl_cffi\curl.py", line 100, in buffer_callback
#     @ffi.def_extern()
# KeyboardInterrupt:
# Skipping JM.ST, not found: Error fetching data for JM.ST: Failed to perform, curl: (23) Failure writing output to destination, passed 17 returned 0. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.

# %%
predictions = agent.predict_future(SWEDISH_STOCKS)
# Out:
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Skipping TELE2-B.ST, not found: Error fetching data for TELE2-B.ST: list index out of range
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Skipping SWMA.ST, not found: Error fetching data for SWMA.ST: list index out of range
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Skipping ZETA.ST, not found: Error fetching data for ZETA.ST: list index out of range
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
agent.evaluate_direction()
# Out:
# 48.33408577878104
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
predictions
# Out:
# [{'ticker': 'ERIC-B.ST', 'predicted_return': np.float32(0.004918957)},
#  {'ticker': 'VOLV-B.ST', 'predicted_return': np.float32(0.0028211372)},
#  {'ticker': 'SAND.ST', 'predicted_return': np.float32(-0.0036204634)},
#  {'ticker': 'SEB-A.ST', 'predicted_return': np.float32(0.008533489)},
#  {'ticker': 'SWED-A.ST', 'predicted_return': np.float32(0.0023686884)},
#  {'ticker': 'ATCO-A.ST', 'predicted_return': np.float32(0.0071094916)},
#  {'ticker': 'ABB.ST', 'predicted_return': np.float32(-0.014387469)},
#  {'ticker': 'ALFA.ST', 'predicted_return': np.float32(-0.010812992)},
#  {'ticker': 'ASSA-B.ST', 'predicted_return': np.float32(-0.0079918355)},
#  {'ticker': 'BOL.ST', 'predicted_return': np.float32(-0.0056458274)},
#  {'ticker': 'ESSITY-B.ST', 'predicted_return': np.float32(0.0008734927)},
#  {'ticker': 'HEXA-B.ST', 'predicted_return': np.float32(-0.001172195)},
#  {'ticker': 'HM-B.ST', 'predicted_return': np.float32(0.0086127445)},
#  {'ticker': 'INVE-B.ST', 'predicted_return': np.float32(0.00016538543)},
#  {'ticker': 'KINV-B.ST', 'predicted_return': np.float32(0.0064798733)},
#  {'ticker': 'NDA-SE.ST', 'predicted_return': np.float32(0.008462707)},
#  {'ticker': 'SAAB-B.ST', 'predicted_return': np.float32(-0.0055314065)},
#  {'ticker': 'SCA-B.ST', 'predicted_return': np.float32(0.00803421)},
#  {'ticker': 'SKF-B.ST', 'predicted_return': np.float32(0.005665799)},
#  {'ticker': 'SSAB-A.ST', 'predicted_return': np.float32(0.006396036)},
#  {'ticker': 'SHB-A.ST', 'predicted_return': np.float32(0.0061106454)},
#  {'ticker': 'TELIA.ST', 'predicted_return': np.float32(0.006731207)},
#  {'ticker': 'TEL2-B.ST', 'predicted_return': np.float32(0.009416591)},
#  {'ticker': 'HUSQ-B.ST', 'predicted_return': np.float32(0.0017223284)},
#  {'ticker': 'BETS-B.ST', 'predicted_return': np.float32(0.0025533654)},
#  {'ticker': 'BILL.ST', 'predicted_return': np.float32(0.0030997568)},
#  {'ticker': 'CAST.ST', 'predicted_return': np.float32(0.0071145487)},
#  {'ticker': 'CINT.ST', 'predicted_return': np.float32(0.01065805)},
#  {'ticker': 'DIOS.ST', 'predicted_return': np.float32(0.0020778743)},
#  {'ticker': 'FABG.ST', 'predicted_return': np.float32(0.007170069)},
#  {'ticker': 'GETI-B.ST', 'predicted_return': np.float32(0.0069955047)},
#  {'ticker': 'HUFV-A.ST', 'predicted_return': np.float32(0.0016607394)},
#  {'ticker': 'INDT.ST', 'predicted_return': np.float32(-0.02750199)},
#  {'ticker': 'JM.ST', 'predicted_return': np.float32(0.001703369)},
#  {'ticker': 'LATO-B.ST', 'predicted_return': np.float32(-0.0006640146)},
#  {'ticker': 'LUND-B.ST', 'predicted_return': np.float32(0.0013885587)},
#  {'ticker': 'MTRS.ST', 'predicted_return': np.float32(-0.0060858596)},
#  {'ticker': 'NIBE-B.ST', 'predicted_return': np.float32(0.007131391)},
#  {'ticker': 'PEAB-B.ST', 'predicted_return': np.float32(-0.0035173441)},
#  {'ticker': 'SAGA-B.ST', 'predicted_return': np.float32(0.0020851817)},
#  {'ticker': 'SOBI.ST', 'predicted_return': np.float32(0.0039471593)},
#  {'ticker': 'THULE.ST', 'predicted_return': np.float32(-0.013392757)},
#  {'ticker': 'TOBII.ST', 'predicted_return': np.float32(0.006523499)},
#  {'ticker': 'VITR.ST', 'predicted_return': np.float32(0.0030492533)},
#  {'ticker': 'WALL-B.ST', 'predicted_return': np.float32(0.0079888925)},
#  {'ticker': 'WIHL.ST', 'predicted_return': np.float32(0.00765744)},
#  {'ticker': 'XANO-B.ST', 'predicted_return': np.float32(0.0020390875)}]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
