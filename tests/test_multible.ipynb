# %%
from backend.components.stock import Stock
from backend.features.models.multi_agent import MultiAgent
from utils.stock_list import SWEDISH_STOCKS

# %%
stock = Stock("saab")
agent = MultiAgent(stock)

history = agent.train_on_multiple(SWEDISH_STOCKS)
# Out:
# Exception ignored from cffi callback <function buffer_callback at 0x00000238374863E0>:
# Traceback (most recent call last):
#   File "c:\Users\milto\Documents\repositories\Market\.venv\Lib\site-packages\curl_cffi\curl.py", line 100, in buffer_callback
#     @ffi.def_extern()
# KeyboardInterrupt:
# Skipping ABB.ST, not found: Error fetching data for ABB.ST: Failed to perform, curl: (23) Failure writing output to destination, passed 13 returned 0. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.

# %%
predictions = agent.predict_future(SWEDISH_STOCKS)
